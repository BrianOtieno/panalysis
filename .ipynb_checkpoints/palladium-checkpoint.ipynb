# %% [markdown]
# # Datababse Syncronization Script - Palladium
# #### About Script
# The script should do the following;
# - Query all the table names in the database
# - Merge all the similar tables in the databases
# - Create a new database
# - dump all the merged tables into the new database.

# %% [markdown]
# #### Import Dependancies

# %%
import pandas as pd 
import mysql.connector
import json
import os
import glob
from sqlalchemy import create_engine

# %%
# host = "192.168.0.200"
host = "localhost"
user = "root"
# password = "irdo@ugunja" 
password = "P@55w0rd."
auth_plugin = "mysql_native_password"

condb = mysql.connector.connect(
    host=host,
    user=user,
    password=password, 
    auth_plugin=auth_plugin
)

cursor = condb.cursor() 
cursor.execute("show databases")

databases = cursor.fetchall()
 
databases = ' '.join(str(v) for v in databases)
databases = "".join(filter(lambda x: x != "(", databases)) 
databases = "".join(filter(lambda x: x != ")", databases)) 
databases = "".join(filter(lambda x: x != ",", databases))
databases = "".join(filter(lambda x: x != "'", databases)) 

databases = databases.split()
excluded_databases = ['information_schema', 'dwapi', 'mysql', 'testdb']
for database in databases:
    if database not in excluded_databases:
#         print(database)
#         cursor.execute("use openmrs;")
#         print(cursor.execute("show tables;"))
#         cursor.execute("use openmrs;")
#         cursor.execute("use openmrs;show tables;", multi=True)
#         tables = cursor.fetchall()
#         for table in tables:
#             print(table) 
        print (database)
# Out:
# emrfix
# irdoweb
# kenyaemr_datatools
# kenyaemr_etl
# openmrs
# openmrs1710
# performance_schema
# sys

# %% [markdown]
# #### Get Databases

# %% [markdown]
# #### Get Tables and Merge

# %%
cursor = condb.cursor() 
db_one = "openmrs"
db_two = "openmrs1710"
cursor.execute("use openmrs")
cursor.execute("show tables")

tables = cursor.fetchall()
 
tables = ' '.join(str(v) for v in tables)
tables = "".join(filter(lambda x: x != "(", tables)) 
tables = "".join(filter(lambda x: x != ")", tables)) 
tables = "".join(filter(lambda x: x != ",", tables))
tables = "".join(filter(lambda x: x != "'", tables)) 

tables = tables.split()

excluded_tables = ['table1', 'table2', 'table3', 'table4']
for table in tables:
    if table not in excluded_tables: 
#         cursor.execute("use openmrs;")
#         print(cursor.execute("show tables;"))
#         cursor.execute("use openmrs;")
#         cursor.execute("use openmrs;show tables;", multi=True)
#         tables = cursor.fetchall()
#         for table in tables:
#             print(table) 
        print (table)
        break
# Out:
# active_list

# %%
for word in values:
    print

# %%
df = pd.read_sql('SELECT * FROM openmrs.users', condb)

def merge_db(table):
    
df.head()
# Out:
#    user_id system_id        username  \
# 0        1     admin
# 1        2    daemon          daemon
# 2        3       3-4  upgradeManager
# 3        4       4-2          ROdeny
# 4        5       5-9          OBrien
#
#                                             password  \
# 0  53879801847b563c883f8b2081d24c17ec85eeaaf92079...
# 1                                               None
# 2  f0474310b852328b7c929c6c8090d4ef8ce01a43cad9eb...
# 3  a7f509b7dfc3125002c8b799e699c96c68df896f1b9446...
# 4  1e65769253c0ae4bed3bf236f7bc5ef6e93ac531b7f523...
#
#                                                 salt secret_question  \
# 0  aa3b861547ae1e6d9dbef33118d183f71e432c3e86f4c9...            None
# 1                                               None            None
# 2  85ea0f4e6771b5a59a4ec742cd81e565a7576711378fab...            None
# 3  98b71e473bbda3fa86a8a7507c00f1df5433c45b7ba416...
# 4  00b11e0c1721bec3c7fef5177fbd35c50bca79527f136b...
#
# ...
